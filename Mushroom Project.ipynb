# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('Display.max_columns',None)

# %%
#Loading datasets
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset1/master/mushrooms.csv")
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color stalk-shape stalk-root  \
# 0               c         n          k           e          e
# 1               c         b          k           e          c
# 2               c         b          n           e          c
# 3               c         n          n           e          e
# 4               w         b          k           t          e
# ...           ...       ...        ...         ...        ...
# 8119            c         b          y           e          ?
# 8120            c         b          y           e          ?
# 8121            c         b          n           e          ?
# 8122            c         n          b           t          ?
# 8123            c         b          y           e          ?
#
#      stalk-surface-above-ring stalk-surface-below-ring stalk-color-above-ring  \
# 0                           s                        s                      w
# 1                           s                        s                      w
# 2                           s                        s                      w
# 3                           s                        s                      w
# 4                           s                        s                      w
# ...                       ...                      ...                    ...
# 8119                        s                        s                      o
# 8120                        s                        s                      o
# 8121                        s                        s                      o
# 8122                        s                        k                      w
# 8123                        s                        s                      o
#
#      stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 0                         w         p          w           o         p
# 1                         w         p          w           o         p
# 2                         w         p          w           o         p
# 3                         w         p          w           o         p
# 4                         w         p          w           o         e
# ...                     ...       ...        ...         ...       ...
# 8119                      o         p          o           o         p
# 8120                      o         p          n           o         p
# 8121                      o         p          o           o         p
# 8122                      w         p          w           o         e
# 8123                      o         p          o           o         p
#
#      spore-print-color population habitat
# 0                    k          s       u
# 1                    n          n       g
# 2                    n          n       m
# 3                    k          s       u
# 4                    n          a       g
# ...                ...        ...     ...
# 8119                 b          c       l
# 8120                 b          v       l
# 8121                 b          c       l
# 8122                 w          v       l
# 8123                 o          c       l
#
# [8124 rows x 23 columns]

# %%
#Checking NaN Values in Data
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
#Lets Analyse each features
for feature in df.columns:
    df[feature].value_counts().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('counts')
    plt.show()

# %% [markdown]
# #Analyses from the above:
#     1 : 'veil-type' has single label.So, we are droping it.
#     2 : 'stalk-root' has '?' label. we will change it to 'o'(other)
#     3 : There are many features having One or Two pre-dominant labels.

# %%
df.drop('veil-type',axis=1,inplace=True)

# %%
df['stalk-root'].unique()
# Out:
# array(['e', 'c', 'b', 'r', '?'], dtype=object)

# %%
df['stalk-root']=np.where(df['stalk-root']=='?','o',df['stalk-root'])

# %% [markdown]
# Lets Rename the output variable(class)to poisonous for our convenience

# %%
df.rename(columns={'class':'poisonous'},inplace=True)

# %%
df['poisonous'].value_counts()
# Out:
# e    4208
# p    3916
# Name: poisonous, dtype: int64

# %%
#Now lets change the poisonous('p')to 1 and eatable('e') to 0
df['poisonous']=np.where(df['poisonous']=='p',1,0)

# %%
df['poisonous'].value_counts()
# Out:
# 0    4208
# 1    3916
# Name: poisonous, dtype: int64

# %%
features=[feature for feature in df.columns if feature != 'poisonous']

# %%
#Analysing every feature with count plot
for feature in features:
    sns.countplot(x=feature,hue='poisonous',data=df)
    plt.show()

# %%
for feature in features:
    df.groupby(feature)['poisonous'].mean().plot.bar()
    plt.xlabel(feature)
    plt.show()

# %% [markdown]
# #analysias from the above data is:
#
# 1.one or more categories in each features having mean=1 & mean=0 which helps us to classify mushrooms easily
# 2.Odor feature holding more information regarding output

# %% [markdown]
# We are using Target guided encoding for handling categorical features because it gives us monotonic relationship with output variable.
#
# We can also use mean encoding.

# %%
df.groupby(['stalk-color-above-ring'])['poisonous'].mean().sort_values()
# Out:
# stalk-color-above-ring
# e    0.000000
# g    0.000000
# o    0.000000
# w    0.383513
# p    0.692308
# n    0.964286
# b    1.000000
# c    1.000000
# y    1.000000
# Name: poisonous, dtype: float64

# %% [markdown]
# Mapping odinal numbers to the labels

# %%
for feature in features:
    ordered_labels=df.groupby([feature])['poisonous'].mean().sort_values().index
    ordinal_labels= {k:i for i,k in enumerate(ordered_labels,0)}
    df[feature]=df[feature].map(ordinal_labels)

# %%
df.groupby(['stalk-color-above-ring'])['poisonous'].mean().sort_values()
# Out:
# stalk-color-above-ring
# 0    0.000000
# 1    0.000000
# 2    0.000000
# 3    0.383513
# 4    0.692308
# 5    0.964286
# 6    1.000000
# 7    1.000000
# 8    1.000000
# Name: poisonous, dtype: float64

# %% [markdown]
# In this way for every feature, we can easily predict whether if value is less than threshold value than it is treated is eatable (0) else poisonous (1)

# %%
df
# Out:
#       poisonous  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0             1          2            2          5        0     6
# 1             0          2            2          8        0     0
# 2             0          1            2          3        0     1
# 3             1          2            1          3        0     6
# 4             0          2            2          4        1     2
# ...         ...        ...          ...        ...      ...   ...
# 8119          0          4            2          5        1     2
# 8120          0          2            2          5        1     2
# 8121          0          3            2          5        1     2
# 8122          1          4            1          5        1     8
# 8123          0          2            2          5        1     2
#
#       gill-attachment  gill-spacing  gill-size  gill-color  stalk-shape  \
# 0                   1             1          1           4            1
# 1                   1             1          0           4            1
# 2                   1             1          0           3            1
# 3                   1             1          1           3            1
# 4                   1             0          0           4            0
# ...               ...           ...        ...         ...          ...
# 8119                0             1          0           6            1
# 8120                0             1          0           6            1
# 8121                0             1          0           3            1
# 8122                1             1          1          10            0
# 8123                0             1          0           6            1
#
#       stalk-root  stalk-surface-above-ring  stalk-surface-below-ring  \
# 0              2                         1                         2
# 1              1                         1                         2
# 2              1                         1                         2
# 3              2                         1                         2
# 4              2                         1                         2
# ...          ...                       ...                       ...
# 8119           4                         1                         2
# 8120           4                         1                         2
# 8121           4                         1                         2
# 8122           4                         1                         3
# 8123           4                         1                         2
#
#       stalk-color-above-ring  stalk-color-below-ring  veil-color  ring-number  \
# 0                          3                       3           2            1
# 1                          3                       3           2            1
# 2                          3                       3           2            1
# 3                          3                       3           2            1
# 4                          3                       3           2            1
# ...                      ...                     ...         ...          ...
# 8119                       2                       2           1            1
# 8120                       2                       2           0            1
# 8121                       2                       2           1            1
# 8122                       3                       3           2            1
# 8123                       2                       2           1            1
#
#       ring-type  spore-print-color  population  habitat
# 0             1                  5           3        5
# 1             1                  4           1        2
# 2             1                  4           1        1
# 3             1                  5           3        5
# 4             2                  4           0        2
# ...         ...                ...         ...      ...
# 8119          1                  0           2        4
# 8120          1                  0           5        4
# 8121          1                  0           2        4
# 8122          2                  6           5        4
# 8123          1                  1           2        4
#
# [8124 rows x 22 columns]

# %% [markdown]
# Monotonic relationship between every feature and Target feature.Hence,This is the reason why we used Target guided encoding.

# %%
for feature in features:
    df.groupby([feature])['poisonous'].mean().plot()
    plt.show()

# %% [markdown]
# for Feature selection we are using SelectKBest, chi2 (chi square).

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
select=SelectKBest(score_func=chi2,k=12)

# %%
feature_scores=select.fit(df.drop('poisonous',axis=1),df['poisonous'])

# %%
feature_scores.scores_
# Out:
# array([8.11627450e+01, 1.40804046e+02, 1.73536708e+02, 8.49174461e+02,
#        6.81937996e+03, 3.50544682e+00, 1.59241838e+02, 1.63660683e+03,
#        4.07407532e+03, 4.79595103e+01, 4.12745451e+02, 1.69875233e+03,
#        4.60417395e+02, 8.39932627e+02, 8.41754028e+02, 5.12682568e+00,
#        2.94729312e+01, 1.01318427e+03, 1.06588501e+03, 9.00407999e+02,
#        9.85479495e+02])

# %% [markdown]
# Scores has been obtained related to every feature with respect to output variable

# %%
scores_df=pd.DataFrame(feature_scores.scores_)
features_df=pd.DataFrame(features)
feature_scores_df=pd.concat([features_df,scores_df],axis=1)
feature_scores_df.columns=['features','score']

# %% [markdown]
# Now lets map each feature with respect to its score

# %%
feature_scores_df.sort_values(by='score',ascending=False,inplace=True)
feature_scores_df
# Out:
#                     features        score
# 4                       odor  6819.379957
# 8                 gill-color  4074.075323
# 11  stalk-surface-above-ring  1698.752334
# 7                  gill-size  1636.606833
# 18         spore-print-color  1065.885011
# 17                 ring-type  1013.184267
# 20                   habitat   985.479495
# 19                population   900.407999
# 3                    bruises   849.174461
# 14    stalk-color-below-ring   841.754028
# 13    stalk-color-above-ring   839.932627
# 12  stalk-surface-below-ring   460.417395
# 10                stalk-root   412.745451
# 2                  cap-color   173.536708
# 6               gill-spacing   159.241838
# 1                cap-surface   140.804046
# 0                  cap-shape    81.162745
# 9                stalk-shape    47.959510
# 16               ring-number    29.472931
# 15                veil-color     5.126826
# 5            gill-attachment     3.505447

# %% [markdown]
# Data Visualization

# %%
feature_scores_df['score'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Selecting which are more than 800

# %%
Best_features=feature_scores_df[feature_scores_df['score']>800]
Best_features
# Out:
#                     features        score
# 4                       odor  6819.379957
# 8                 gill-color  4074.075323
# 11  stalk-surface-above-ring  1698.752334
# 7                  gill-size  1636.606833
# 18         spore-print-color  1065.885011
# 17                 ring-type  1013.184267
# 20                   habitat   985.479495
# 19                population   900.407999
# 3                    bruises   849.174461
# 14    stalk-color-below-ring   841.754028
# 13    stalk-color-above-ring   839.932627

# %%
sns.barplot(x='features',y='score',data=Best_features)
# Out:
# <AxesSubplot:xlabel='features', ylabel='score'>

# %%
Best_features = Best_features['features'].values
Best_features
# Out:
# array(['odor', 'gill-color', 'stalk-surface-above-ring', 'gill-size',
#        'spore-print-color', 'ring-type', 'habitat', 'population',
#        'bruises', 'stalk-color-below-ring', 'stalk-color-above-ring'],
#       dtype=object)

# %%
plt.figure(figsize=(20,30))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# From above, we can notice that odor, gill-color, ring-type, spore-print-color are correlated more than 60% with respect to output variable.
#
# We are splitting our Dataset into training and testing with the help of train_test_split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df[Best_features],df['poisonous'],test_size=0.2,random_state=0)
X_train
# Out:
#       odor  gill-color  stalk-surface-above-ring  gill-size  \
# 7434     2           7                         1          0
# 7725     2           8                         1          0
# 783      1           3                         1          0
# 1928     2           9                         1          0
# 7466     8          10                         1          1
# ...    ...         ...                       ...        ...
# 4931     2           0                         1          0
# 3264     4           9                         3          0
# 1653     2           9                         0          0
# 2607     2           3                         1          0
# 2732     2           5                         1          0
#
#       spore-print-color  ring-type  habitat  population  bruises  \
# 7434                  6          1        2           3        1
# 7725                  6          1        2           1        1
# 783                   5          1        1           3        0
# 1928                  5          2        2           3        1
# 7466                  6          2        4           5        1
# ...                 ...        ...      ...         ...      ...
# 4931                  6          2        0           2        0
# 3264                  7          3        6           4        1
# 1653                  4          2        2           3        1
# 2607                  4          1        3           5        0
# 2732                  4          1        3           4        0
#
#       stalk-color-below-ring  stalk-color-above-ring
# 7434                       3                       3
# 7725                       3                       3
# 783                        3                       3
# 1928                       3                       3
# 7466                       4                       3
# ...                      ...                     ...
# 4931                       0                       0
# 3264                       5                       4
# 1653                       3                       3
# 2607                       1                       1
# 2732                       4                       1
#
# [6499 rows x 11 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,roc_auc_score

# %% [raw]
# Good Feature engineering, Feature selection and Balanced Dataset we got Maximum accuracy for all the above models

# %%
model = KNeighborsClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_predict = model.predict(X_test)

# %%
y_pred_proba0 = model.predict_proba(X_train)

# %%
y_pred_proba1 = model.predict_proba(X_test)

# %%
roc_auc_score(y_train,y_pred_proba0[:,1])
# Out:
# 1.0

# %%
roc_auc_score(y_test,y_pred_proba1[:,1])
# Out:
# 1.0

# %%
confusion_matrix(y_test,y_predict)
# Out:
# array([[852,   0],
#        [  0, 773]], dtype=int64)

# %%
accuracy_score(y_test,y_predict)
# Out:
# 1.0

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(model,df[Best_features].sample(frac=1,random_state=0),df['poisonous'].sample(frac=1,random_state=0),cv=5)
# Out:
# array([1., 1., 1., 1., 1.])

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_predict = model.predict(X_test)

# %%
y_pred_proba0 = model.predict_proba(X_train)

# %%
y_pred_proba1 = model.predict_proba(X_test)

# %%
roc_auc_score(y_train,y_pred_proba0[:,1])
# Out:
# 1.0

# %%
roc_auc_score(y_test,y_pred_proba1[:,1])
# Out:
# 1.0

# %%
confusion_matrix(y_test,y_predict)
# Out:
# array([[852,   0],
#        [  0, 773]], dtype=int64)

# %%
accuracy_score(y_test,y_predict)
# Out:
# 1.0

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(model,df[Best_features].sample(frac=1,random_state=0),df['poisonous'].sample(frac=1,random_state=0),cv=5)
# Out:
# array([1., 1., 1., 1., 1.])

# %%
model = RandomForestClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_predict = model.predict(X_test)

# %%
y_pred_proba0 = model.predict_proba(X_train)

# %%
y_pred_proba1 = model.predict_proba(X_test)

# %%
roc_auc_score(y_train,y_pred_proba0[:,1])
# Out:
# 1.0

# %%
roc_auc_score(y_test,y_pred_proba1[:,1])
# Out:
# 1.0

# %%
confusion_matrix(y_test,y_predict)
# Out:
# array([[852,   0],
#        [  0, 773]], dtype=int64)

# %%
accuracy_score(y_test,y_predict)
# Out:
# 1.0

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(model,df[Best_features].sample(frac=1,random_state=0),df['poisonous'].sample(frac=1,random_state=0),cv=5)
# Out:
# array([1., 1., 1., 1., 1.])
